# %% [markdown]
# # 👍 중간고사 - 미완성 문제해결 프로그램

# %% [markdown]
# ## [시험문제]
# - 주석의 안내에 따라 미완성 프로그램을 완성하고, 중간고사 시험문제 16번 ~ 20번까지의 질문에 답하세요.

# %% [markdown]
# ## [문제상황 - 해결할 문제 정의]

# %% [markdown]
# - 네이버 검색엔진을 이용하여 “데이터 분석”을 키워드로 하여 검색한 결과를
# - 제목, 상세 경로 등 여러가지 정보를 수집하여 파일로 저장하는 스크래핑 프로그램을 완성하세요.

# %% [markdown]
# - 접속 사이트 : https://search.naver.com/search.naver?where=m_view&sm=mtb_jum&query=

# %% [markdown]
# - 수집 대상 : '데이터 분석' 키워드 조회결과

# %% [markdown]
# # 조회결과 스크래핑

# %%
# 필요한 모듈 로딩
import pandas as pd  # 문제 2-1 : pandas 패키지를 pd라는 이름으로 사용하기 위한 코드를 완성하세요.
import numpy as np # 문제 2-2 : numpy 패키지를 np라는 이름으로 사용하기 위한 코드를 완성하세요.
import re

import requests
from bs4 import BeautifulSoup
import csv

import datetime

# %%
# "데이터 분석" 키워드를 이용하여 네이버 검색결과인 원시 데이터를 수집
key_word = '데이터 분석'
url = f'https://m.search.naver.com/search.naver?where=m_view&sm=mtb_jum&query={key_word}'
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

 # 문제 2-3 : 수신한 데이터(html)를 구문 분석하여 접근하기 쉽도록 처리하는 코드를 완성하세요.
# soup = BeautifulSoup(html.content, 'html.parser')

# %%
# 일단 원시 데이터를 보조 기억장치에 저장한다.
# 하단의 프로그램을 실행하는 도중 문제 발생시 다시 검색하는 번거로움과 시간을 절약할 수 있다.
f = open('search_result_source.txt', 'w')
f.write(html.content.decode('utf-8'))
# Out:
# 288463

# %%
# 저장된 검색 결과 데이터 파일을 읽기
f = open('search_result_source.txt')
html = f.read()  # 문제 2-4 : 파일에서 데이터를 모두 읽는 함수를 완성하세요.
soup = BeautifulSoup(html, 'html.parser')
# f 변수는 파일 객체(file object)입니다. 파일 객체는 파일을 다루기 위한 함수들을 제공하는데, 파일을 생성, 열기, 읽기, 쓰기, 닫기 등을 처리할 수 있습니다.

# %%
# "bx _svp_item _slog_visible" CSS를 사용하는 Tag를 찾는다.
search_result_cards = soup.find_all('li', class_='bx _svp_item _slog_visible')
len(search_result_cards)

# soup.find_all('div', {'class': 'my-class'})와 같은 형태로 사용하면, class 속성 값이 my-class인 모든 div 태그를 찾을 수 있습니다.
# Out:
# 30

# %%
# 찾은 Tag 중 첫번째 데이터를 출력해 본다.
search_result_cards[0]
# Out:
# <li class="bx _svp_item _slog_visible" data-cr-area="rvw*x" data-cr-gdid="90000003_0000000000000033EFC11285" data-cr-rank="1" data-slog-content="rvw*x:90000003_0000000000000033EFC11285"> <div class="total_wrap"> <div class="api_save_group _keep_wrap"> <a class="btn_save _keep_trigger" data-url="https://m.blog.naver.com/mintsorbet07/223065739909" href="#" onclick="tCR('a=rvw*x.kep&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=rvw*x.kepoff&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u=javascript" data-cr-on="a=rvw*x.kepon&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://m.keep.naver.com/" onclick="return goOtherCR(this,'a=rvw*x.kephome&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div> </div><div class="total_sub"> <a class="sub_thumb" href="https://m.blog.naver.com/mintsorbet07" onclick="return goOtherCR(this, 'a=rvw*x.writer&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u='+urlencode(this.href))"> <span class="thumb"> <img alt="" class="" height="24" onerror="this.src='...';this.className='bg_npimg'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogpfthumb.phinf.naver.net%2F20140221_144%2Fmintsorbet07_1392956062762v6cw3_JPEG%2FIMG_2535.jpg&amp;type=f54_54" width="24"/> </span></a><span class="elss etc_dsc"> <span class="etc_dsc_group"> <span class="etc_dsc_area"> <span class="sub_time sub_txt">2023.04.06.</span> </span><span class="elss etc_dsc_inner"> <a class="sub_txt sub_name" href="https://m.blog.naver.com/mintsorbet07" onclick="return goOtherCR(this, 'a=rvw*x.writer&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u='+urlencode(this.href))">song's eyagi</a> </span></span></span></div><a class="api_txt_lines total_tit _cross_trigger" data-cr-gdid="90000003_0000000000000033EFC11285" href="https://m.blog.naver.com/mintsorbet07/223065739909" onclick="return goOtherCR(this, 'a=rvw*x.link&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u='+urlencode(this.href))">빅<mark>데이터분석</mark>기사 응시자격 확인 및 학습과정</a> <div class="api_list_scroll_wrap review_thumb_group _svp_content" style="height: 93px;"> <div> <ul class="api_list_scroll"> <li class="bx"> <a class="thumb _cross_trigger" data-cr-gdid="90000003_0000000000000033EFC11285" href="https://m.blog.naver.com/mintsorbet07/223065739909" onclick="return goOtherCR(this, 'a=rvw*x.link&amp;r=1&amp;i=90000003_0000000000000033EFC11285&amp;u='+urlencode(this.href))"> <img alt="" class="_vsb_img _cover_image" data-error-class="bg_nimg2" data-img-src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA0MDVfMjgz%2FMDAxNjgwNjgxMDI1MzA3.nFCEiy-P25KFKSflOfsMiOGotKgge5o0vq80sSHEm6Ag.X_AYxtE04BH-NZfnQUtoTJcygEujE1KJi9HGzJOwhdsg.JPEG.mintsorbet07%2F%25BD%25E6%25B3%25D7%25C0%25CF%2529.jpg%23900x900&amp;type=b220" height="93" src="..."/> </a> </li> <li class="bx"> <a class="thumb _svp_trigger" data-api="https://s.search.naver.com/p/videosearch/search.naver?where=playinfo&amp;type=nmv&amp;key=IggCAAmCULhYAAAA53SD0oV3jFkek1VGlI2ajB7qj7NyXNAsaHuPYFfaFYC2rlgKEjetjiuEGOpHrV53" data-auto-play="true" data-is-visible-close-btn="true" data-source="naver" href="javascript:;"> <img alt="" class="_vsb_img _cover_image" data-error-class="bg_nimg2" data-img-src="https://search.pstatic.net/common/?src=http%3A%2F%2Fimage.nmv.naver.net%2Fblog_2023_04_05_2966%2F71912776-d386-11ed-b597-a0369ffabdf8_01.jpg%23m&amp;type=f302_186" height="93" src="..."/> <span class="api_video_mask"><i class="spnew api_ico_video">동영상</i></span> <span aria-label="재생시간 00:34" class="api_time">00:34</span> </a> </li> <li class="bx"> <a class="thumb _cross_trigger" data-cr-gdid="90000003_0000000000000033EFC11285" href="https://m.blog.naver.com ...

# %%
# 수집 대상이 되는 출처URL, 출처명, 작성일자, 제목, 제목클릭시 이동 URL, 제목클릭시 실행함수, 요약 내용 데이터를 수집한다.
# 수집된 데이터는 data_list 객체에 저장한다.
data_list = []
for card in search_result_cards:
    temp = []

    # 출처 URL 수집
    try:
        card_source = card.select('.elss.etc_dsc_inner')[0].a
    except:
        card_source = card.select('.source_link')[0]
    # 문제 2-6 : 출처 URL을 수집하기 위한 알맞은 이름을 완성하세요. (이미 코드가 완성되어서 시험문제로 제출하지 않습니다.)
    # 답: card_source입니다.
    temp.append(card_source['href']) # 출처 URL

    # 출처명 수집
    try:
        card_source = card.select('.elss.etc_dsc_inner')[0].a
    except:
        card_source = card.select('.source_txt.name')[0]
    # 문제 2-7 : 출처명을 수집하기 위한 알맞은 변수명을 완성하세요.
    temp.append(card_source.text)  # 출처명

    # 작성일자 수집
    try:
        card_date = card.select('.sub_time.sub_txt')[0]
    except:
        card_date = card.select('.source_txt.date')[0]
    # 문제 2-8 : 작성일자를 수집하기 위한 알맞은 변수명을 완성하세요.
    temp.append(card_date.text.strip()) # 작성일자

    # 제목, 제목클릭시 이동 URL, 제목클릭시 실행함수 수집
    card_title = card.select('.api_txt_lines.total_tit')[0]
    try:
        temp.append(card_title['href']) # 제목 클릭시 이동하는 URL
        temp.append(card_title.attrs['onclick']) # 제목 클릭시 실행하는 함수
        temp.append(card_title.text) # 제목
    except:
        temp.append(np.NaN) # 제목 클릭시 이동하는 URL 결측치 처리
        temp.append(np.NaN) # 제목 클릭시 실행하는 함수 결측치 처리
        temp.append(np.NaN) # 제목 결측치 처리

    # 요약 내용 수집
    card_contents = card.select('.api_txt_lines.dsc_txt')[0]
    temp.append(card_contents.text) # 요약 내용

    data_list.append(temp)

# %%
# 수집된 데이터가 저장된 data_list를 DataFrame객체로 변환한다.
# 문제 2-9 : pandas 데이터프레임으로 변환하기 위한 함수를 완성하세요.
df_data_list = pd.DataFrame(data_list, columns=['출처 URL',
                                                '출처명',
                                                '작성일자',
                                                '제목 클릭 이동 URL',
                                                '제목 클릭 실행 함수',
                                                '제목',
                                                '요약내용'])

# %%
# 변환된 df_data_list객체를 출력해 본다.
df_data_list
# Out:
#                                                출처 URL  \
# 0               https://m.blog.naver.com/mintsorbet07
# 1                   https://m.blog.naver.com/jdnxx8z5
# 2   https://m.post.naver.com/my.naver?memberNo=645...
# 3                    https://m.blog.naver.com/urmyver
# 4                  https://m.blog.naver.com/waiting25
# 5                    https://m.cafe.naver.com/winspec
# 6                   https://m.blog.naver.com/jblove80
# 7                       https://in.naver.com/feia1230
# 8                    https://m.blog.naver.com/osojang
# 9                   https://m.cafe.naver.com/statclub
# 10                  https://m.blog.naver.com/ridesafe
# 11                https://m.blog.naver.com/bestoxford
# 12                 https://m.blog.naver.com/hhee_0211
# 13                     https://in.naver.com/hellstudy
# 14                https://m.blog.naver.com/wonsstorne
# 15             https://m.blog.naver.com/roseandme7753
# 16                    https://m.blog.naver.com/182544
# 17                   https://m.cafe.naver.com/mseller
# 18                 https://m.blog.naver.com/raonday92
# 19                    https://m.cafe.naver.com/specup
# 20                     https://m.cafe.naver.com/sqlpd
# 21                 https://m.blog.naver.com/withkisti
# 22                   https://m.cafe.naver.com/winspec
# 23          https://m.cafe.naver.com/studentstudyhard
# 24                   https://m.blog.naver.com/moeblog
# 25                   https://m.cafe.naver.com/yjbooks
# 26                        https://in.naver.com/webkim
# 27                    https://m.blog.naver.com/she_op
# 28                     https://m.cafe.naver.com/sqlpd
# 29             https://m.cafe.naver.com/bebettergirls
#
#                                         출처명         작성일자  \
# 0                              song's eyagi  2023.04.06.
# 1                                       바밤바         4일 전
# 2                                    모비인사이드  2023.03.10.
# 3                   주들의 그리 대단하진 않지만 굉장한 이야기  2023.03.22.
# 4                               스터디채널 공식블로그  2023.04.07.
# 5          윈스펙｜자기계발, 내일배움카드, 토익스피킹, 공기업직업교육  2023.04.06.
# 6                                  jblove80         3일 전
# 7                                      혀니파파  2023.04.07.
# 8                                  이룸114부동산  2023.03.28.
# 9             사회조사분석사 (S&Y) [조사/통계/SPSS/분석]  2023.04.04.
# 10                                비비디 바비디 부  2023.03.28.
# 11             -봉무동이시아폴리스 옥스포드어학원-중3, 수능마무리  2023.03.11.
# 12                        볼빨간 유부♡(,,>᎑<,,)♡  2023.03.16.
# 13                                       루멘  2023.01.11.
# 14                           WHIT ME MENTOS  2023.03.19.
# 15                                     인테리어  2023.03.31.
# 16                         Innocent Promise  2023.04.06.
# 17           자격증 뽀개기★전기기사,전기산업기사,전기기능사,공사기사  2023.04.06.
# 18                               구름이 쉬어가는 밤         5일 전
# 19      스펙업｜취업,대학생,인턴,대기업,공기업,GSAT,대외활동,공모전  2023.04.07.
# 20  데이터 전문가 포럼 (빅데이터분석기사, ADP, SQLP, DAP 등)  2023.03.28.
# 21                한국과학기술정보연구원(KISTI) 공식 블로그  2023.03.22.
# 22         윈스펙｜자기계발, 내일배움카드, 토익스피킹, 공기업직업교육  2023.02.27.
# 23      공준모★공기업,채용,공공기관취업,NCS,자소서,인턴,공무직,한전  2023.02.10.
# 24                                      교육부         7일 전
# 25             이기적 스터디 카페_컴활,정보처리,워드,데이터자격증         7일 전
# 26                                   외식경영박사  2023.01.17.
# 27                       Excuse 美 Agnes : )  2023.03.22.
# 28  데이터 전문가 포럼 (빅데이터분석기사, ADP, SQLP, DAP 등)        3시간 전
# 29     취업대학교★대기업,공기업,GSAT,NCS,인턴,승무원,자소서,면접  2023.03.29.
#
#                                          제목 클릭 이동 URL  \
# 0   https://m.blog.naver.com/mintsorbet07/22306573...
# 1      https://m.blog.naver.com/jdnxx8z5/223073500429
# 2   https://m.post.naver.com/viewer/postView.naver...
# 3       https://m.blog.naver.com/urmyver/223052450425
# 4     https://m.blog.naver.com/waiting25/223067557203
# 5   https://m.cafe.naver.com/winspec/520414?art=ZX...
# 6      https://m.blog.naver.com/jblove80/223074260426
# 7      https://m.blog.naver.com/feia1230/223067522018
# 8       https://m.blog.naver.com/osojang/223058278536
# 9   https://m.cafe.naver.com/statclub/166670?art=Z...
# 10     https://m.blog.naver.com/ridesafe/223058079560
# 11   https://m.blog.naver.com/bestoxford/223040724738
# 12    https://m.blog.naver.com/hhee_0211/223046626195
# 13    https://m.blog.naver.com/hellstudy/222980833110
# 14   https://m.blog.naver.com/wonsstorne/223047495669
# 15  https://m.blog.naver.com/roseandme7753/2230606...
# 16       https://m.blog.naver.com/182544/223066859137
# 17  https://m.cafe.naver.com/mseller/77906?art=ZXh...
# 18    https://m.blog.naver.com/raonday92/223072613372
# 19  https://m.cafe.naver.com/specup/7252794?art=ZX...
# 20  https://m.cafe.naver.com/sqlpd/50740?art=ZXh0Z...
# 21    https://m.blog.naver.com/withkisti/223052086923
# 22  https://m.cafe.naver.com/winspec/451811?art=ZX...
# 23  https://m.cafe.naver.com/studentstudyhard/2278...
# 24      https://m.blog.naver.com/moeblog/223067500457
# 25  https://m.cafe.naver.com/yjbooks/83957?art=ZXh...
# 26       https://m.blog.naver.com/webkim/222987223321
# 27       https://m.blog.naver.com/she_op/223052780382
# 28  https://m.cafe.naver.com/sqlpd/51763?art=ZXh0Z...
# 29  https://m.cafe.naver.com/bebettergirls/1965648...
#
#                                           제목 클릭 실행 함수  \
# 0   return goOtherCR(this, 'a=rvw*x.link&r=1&i=900...
# 1   return goOtherCR(this, 'a=rvw*b.link&r=2&i=900...
# 2   return goOtherCR(this, 'a=rvw*p.link&r=3&i=000...
# 3   return goOtherCR(this, 'a=rvw*b.link&r=4&i=900...
# 4   return goOtherCR(this, 'a=rvw*x.link&r=5&i=900...
# 5   return goOtherCR(this, 'a=rvw*t.link&r=6&i=900...
# 6   return goOtherCR(this, 'a=rvw*b.link&r=7&i=900...
# 7   return goOtherCR(this, 'a=rvw*w.link&r=8&i=900...
# 8   return goOtherCR(this, 'a=rvw*b.link&r=9&i=900...
# 9   return goOtherCR(this, 'a=rvw*t.link&r=10&i=90...
# 10  return goOtherCR(this, 'a=rvw*b.link&r=13&i=90...
# 11  return goOtherCR(this, 'a=rvw*b.link&r=14&i=90...
# 12  return goOtherCR(this, 'a=rvw*b.link&r=15&i=90...
# 13  return goOtherCR(this, 'a=rvw*f.link&r=16&i=90...
# 14  return goOtherCR(this, 'a=rvw*b.link&r=17&i=90...
# 15  return goOtherCR(this, 'a=rvw*b.link&r=18&i=90...
# 16  return goOtherCR(this, 'a=rvw*b.link&r=19&i=90...
# 17  return goOtherCR(this, 'a=rvw*t.link&r=20&i=90...
# 18  return goOtherCR(this, 'a=rvw*b.link&r=21&i=90...
# 19  return goOtherCR(this, 'a=rvw*t.link&r=22&i=90...
# 20  return goOtherCR(this, 'a=rvw*c.link&r=23&i=90...
# 21  return goOtherCR(this, 'a=rvw*b.link&r=24&i=90...
# 22  return goOtherCR(this, 'a=rvw*t.link&r=25&i=90...
# 23  return goOtherCR(this, 'a=rvw*t.link&r=26&i=90...
# 24  return goOtherCR(this, 'a=rvw*b.link&r=27&i=90...
# 25  return goOtherCR(this, 'a=rvw*t.link&r=28&i=90...
# 26  return goOtherCR(this, 'a=rvw*f.link&r=29&i=90...
# 27  return goOtherCR(this, 'a=rvw*b.link&r=30&i=90...
# 28  return goOtherCR(this, 'a=rvw*c.link&r=31&i=90...
# 29  return goOtherCR(this, 'a=rvw*t.link&r=32&i=90...
#
#                                                    제목  \
# 0                             빅데이터분석기사 응시자격 확인 및 학습과정
# 1                               빅데이터분석기사 자격증 온라인 학습과정
# 2                       퍼포먼스 마케터가 데이터 분석 툴을 다뤄야 하는 이유
# 3                       데이터 분석가 : 원활한 취업을 위해 갖춰야 할 스펙
# 4                       빅데이터분석기사 자격증 강의로 필기 합격 자신감 완성
# 5                           빅데이터분석기사 시험일정, 시험시간 체크하기!
# 6                                 빅데이터분석기사 시험일정 확인하세요
# 7                   빅데이터분석기사 AI 시대 앞서나가는 빅데이터자격증 취득방법
# 8                           빅데이터분석기사 시험정보 확인하고 대비했어요!
# 9                          빅데이터분석기사 응시자격 : 가장 합리적인 방법
# 10                      데이터분석 준전문가 학원 : 빅데이터 기초부터 한번에
# 11                        빅데이터분석기사 자격증 취득조건 알아보고 준비하기
# 12                        빅데이터분석교육 :: 빅데이터학원에서 배우세요!!
# 13            2023년 빅데이터분석기사 자격증 시험일정(ADsP/DAsP/SQLD)
# 14                           빅데이터분석기사 응시자격 누가 제일 빠르나~
# 15                            데이터 분석가 취업이 신입으로 어려운 이유
# 16                              데이터분석준전문가 시험정보 및 취득방법
# 17                       빅데이터분석기사 필기 인강 합격률 올리기에 좋아요!
# 18                  빅데이터분석기사 자격요건 고졸 전문대졸도 학점은행제로 준비!
# 19                    [KIC캠퍼스] 자바기반 백엔드 & 빅데이터분석 양성과정
# 20                                 데이터 분석가 스터디 충원(마감)
# 21                      [KISTI 이벤트] '데이터분석본부' 영역 모의고사
# 22                        빅데이터분석기사 필기 시험일정/접수시간 알아보기!
# 23                    빅데이터분석기사 응시자격 온라인으로 최단기간에 준비하는법
# 24                                제5회 교육 공공데이터 분석활용대회
# 25                                제6회 빅데이터 분석기사 필기 후기
# 26  [2023년 1학기 외식업 빅데이터 분석과 활용] 11주차 수업, 데이터 분석 및 시각화
# 27                            빅데이터분석기사 교육받고 자격증 취득하기!
# 28                 '데이터분석'분야 실무 자격증이나 진로방향 조언 부탁드립니다.
# 29                                             데이터 분석
#
#                                                  요약내용
# 0   빅데이터분석기사 시험을 과목별로 분류해 살피자면 필기는 빅데이터 분석기획과 탐색, ...
# 1   빅데이터분석기사는 빅데이터 집합에서 유용한 정보를 찾아서 결과 예측을 위한 데이터를...
# 2   특히 데이터 분석가 중에서도 마케팅 쪽에서 데이터를 분석해보고 싶다는 니즈가 있었거...
# 3   #담당 업무 데이터 분석가가 담당하는 업무는 말 그대로 데이터를 분석하는 업무라서 ...
# 4   빅데이터 분석기사는 이러한 빅데이터에 대한 이해를 기반으로 분석 기획, 수집,저장 ...
# 5   빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 ...
# 6   근무하면서 데이터 분석을 통해 사용자들의 요구를 충족시키는 것을 파악하고 그것에 대...
# 7   그래서 빅데이터분석기사란 이러한 데이터의 분석 기획 그리고 수집 및 저장과 처리 그...
# 8   빅데이터 분석기획 2. 빅데이터 탐색 3. 빅데이터모델링 4. 빅데이터결과해석 이렇...
# 9   빅데이터분석기사 응시자격 : 가장 합리적인 방법 현대 사회를 보게되면 전문자격을 취...
# 10  마스터플랜 데이터 분석 - R기초와 데이터 마트 - 통계분석 - 정형 데이터 마이닝...
# 11  이를 토대로 데이터 분석 프로세스를 나눠 순차적으로 데이터를 수집 / 분석 / 해석...
# 12  가공&분석, 시각화까지 전부 핵심 기술들을 배워서 업무에 활용하거나 커리어에 도움 ...
# 13  [한전 자격가점 분야] [인국공 자격가점 분야] 경쟁이 가장 치열한 행정직의 경우 ...
# 14  마케팅 부서에서 제가 주로 하는 일은 데이터 분석을 하면서 인터넷 포털에 저희 사이...
# 15  신입 채용이 거의 없는 직무 - 기획자 성향 - 의사 결정자 성향 현업에서 데이터 ...
# 16  저는 취업 준비를 위해서 다양한 정보를 알아보던 중 데이터를 분석하는 전문가의 전망...
# 17  빅데이터분석기사 빅데이터 분석기사는 빅데이터 이해를 기반으로 분석 기획, 빅데이터 ...
# 18  먼저 빅데이터분석기사를 보기 위한 한국데이터진흥원에서 정해놓은 조건부터... 동일직...
# 19  빅데이터분석 양성과정 ○ 활동내용 기초부터 실무프로젝트완성 취업지원까지 전액무료교육...
# 20  현재 데이터 분석 스터디를 진행중인데 인원이 적어서 2~3명 정도 충원하려고 합니다...
# 21  한국과학기술정보연구원 유튜브 채널에 올라간 '"데이터 분석해 인사이트 드려요" 데이...
# 22  빅데이터분석기사 필기 시험의 시험시간은 총 120분이며, 빅데이터 분석기획 / 빅데...
# 23  관리하며 분석하는 직업을 빅데이터 분석기사라고 하죠 빅데이터를 관리하기 위해서는 매...
# 24  kr " " #교육공공데이터 #분석활용대회 #교육부 제5회 교육 공공데이터 분석활용...
# 25  제6회 빅데이터 분석기사 필기 시험을 응시한 직장인입니다. 전공은... 공부는 [2...
# 26  문서 속에 숨겨진 주제를 찾는 빅데이터 분석을 위한 통계적 모델 중의 하나입니다. ...
# 27  이에 따라 정형 및 비정형의 대용량 데이터를 구축, 탐색과 분석, 시각화하는 실습형...
# 28  개발/데이터분석 공모전 수상 등) 인데요 실무에 필요하고 도움이 많이 된다면 당연히...
# 29  데이터 분석 관련 자격증 비전공자가 따기 많이 어려울까요? 따 놓으면 마케팅 쪽에서...

# %%
# 25번째 Row만 확인한다. "작성일자" 컬럼 값이 "6일 전"으로 되어있다.
# 문제 2-10 : 25번째 Row를 확인하기 위한 코드를 완성하세요. (이미 코드가 완성되지 않아서 시험문제로 제출되지 않습니다.)
df_data_list.iloc[25]
# Out:
# 출처 URL                           https://m.cafe.naver.com/yjbooks
# 출처명                                  이기적 스터디 카페_컴활,정보처리,워드,데이터자격증
# 작성일자                                                         7일 전
# 제목 클릭 이동 URL    https://m.cafe.naver.com/yjbooks/83957?art=ZXh...
# 제목 클릭 실행 함수     return goOtherCR(this, 'a=rvw*t.link&r=28&i=90...
# 제목                                            제6회 빅데이터 분석기사 필기 후기
# 요약내용            제6회 빅데이터 분석기사 필기 시험을 응시한 직장인입니다. 전공은... 공부는 [2...
# Name: 25, dtype: object

# %%
# "작성일자" 컬럼의 값은 날짜형식이기 때문에 일관성을 갖도록 숫자를 제외한 모든 문자를 제거한다.
# 문자열에서 숫자만을 선택하는 함수 제작
def get_number(x):
    # 만일을 위해, x 값이 숫자형 데이터인 경우 오류가 발생하지 않도록 문자열 데이터로 변환한다.
    x = str(x)
    # x 값에서 공백을 제거한다.
    x = x.replace(' ', '')

    # x 값이 "n일전"과 같은 표현의 경우 현재날짜에서 n일을 빼서 날짜를 만든다.
    if '일전' in x:  # x 문자열에 '일정'이라는 문자를 포함한다면
        n = x.replace('일전', '')  # '일전' 문자를 제거하여 숫자만 남도록 한다.
        n = int(n)  # 숫자만 남았으나 숫자형 변수로 변환한다.
        today = datetime.datetime.now() # 오늘 날짜, 시간을 구한다.
        today_n_ago = today - datetime.timedelta(days=n) # 오늘 날짜에서 n일을 뺀다.
        numbers = today_n_ago.strftime('%Y%m%d') # 날짜 자료형을 "YYYYMMDD"형식으로 변환한다.
    else: # x 문자열에 '일정'이라는 문자를 포함하지 않는다면
        numbers = re.sub('[^0-9]', '', str(x)) # 문자열에서 숫자를 제외한 모든 문자를 제거한다.
    return numbers

# 문자열에서 숫자만을 선택하는 함수를 이용하여 각 Row의 "작성일자" 컬럼값에서 숫자만 가져와서 업데이트한다.
df_data_list['작성일자'] = df_data_list['작성일자'].apply(get_number)

# %%
# 25번째 Row만 확인한다. "작성일자" 컬럼 값이 "6일 전"이 아닌 현재 날짜 이전 6일로 되어있다.
# 문제 2-10 : 25번째 Row를 확인하기 위한 코드를 완성하세요. (이미 코드가 완성되지 않아서 시험문제로 제출되지 않습니다.)
df_data_list.iloc[25]
# Out:
# 출처 URL                           https://m.cafe.naver.com/yjbooks
# 출처명                                  이기적 스터디 카페_컴활,정보처리,워드,데이터자격증
# 작성일자                                                     20230409
# 제목 클릭 이동 URL    https://m.cafe.naver.com/yjbooks/83957?art=ZXh...
# 제목 클릭 실행 함수     return goOtherCR(this, 'a=rvw*t.link&r=28&i=90...
# 제목                                            제6회 빅데이터 분석기사 필기 후기
# 요약내용            제6회 빅데이터 분석기사 필기 시험을 응시한 직장인입니다. 전공은... 공부는 [2...
# Name: 25, dtype: object

# %%
# 수집된 데이터의 "작성일자"가 언제부터 ~ 언제까지인지 조사한다.
# 문제 2-11 : 작성일자 컬럼의 최대값을 구하는 함수를 완성하세요.
# 문제 2-12 : 작성일자 컬럼의 최소값을 구하는 함수를 완성하세요.
df_data_list['작성일자'].max(), df_data_list['작성일자'].min()
# Out:
# ('3', '20230111')

# %%
# DataFrame객체를 저장한다.
# 단, 자동 생성된 index는 필요하지 않기 때문에 제외한다.
# 문제 2-13 : 데이터프레임 객체를 저장하기 위한 함수를 완성하세요.
df_data_list.to_csv('search_result_source.csv', index=False)

# %%
# 저장된 파일목록을 확인한다.
import glob
glob.glob('./**')
# Out:
# ['./search_result_source.csv', './search_result_source.txt', './sample_data']

# %%
# 저장된 파일의 내용을 확인한다.
# 문제 2-14 : 저장된 CSV파일을 읽기 위한 코드를 완성하세요.
df = pd.read_csv('search_result_source.csv')

df
# Out:
#                                                출처 URL  \
# 0               https://m.blog.naver.com/mintsorbet07
# 1                   https://m.blog.naver.com/jdnxx8z5
# 2   https://m.post.naver.com/my.naver?memberNo=645...
# 3                    https://m.blog.naver.com/urmyver
# 4                  https://m.blog.naver.com/waiting25
# 5                    https://m.cafe.naver.com/winspec
# 6                   https://m.blog.naver.com/jblove80
# 7                       https://in.naver.com/feia1230
# 8                    https://m.blog.naver.com/osojang
# 9                   https://m.cafe.naver.com/statclub
# 10                  https://m.blog.naver.com/ridesafe
# 11                https://m.blog.naver.com/bestoxford
# 12                 https://m.blog.naver.com/hhee_0211
# 13                     https://in.naver.com/hellstudy
# 14                https://m.blog.naver.com/wonsstorne
# 15             https://m.blog.naver.com/roseandme7753
# 16                    https://m.blog.naver.com/182544
# 17                   https://m.cafe.naver.com/mseller
# 18                 https://m.blog.naver.com/raonday92
# 19                    https://m.cafe.naver.com/specup
# 20                     https://m.cafe.naver.com/sqlpd
# 21                 https://m.blog.naver.com/withkisti
# 22                   https://m.cafe.naver.com/winspec
# 23          https://m.cafe.naver.com/studentstudyhard
# 24                   https://m.blog.naver.com/moeblog
# 25                   https://m.cafe.naver.com/yjbooks
# 26                        https://in.naver.com/webkim
# 27                    https://m.blog.naver.com/she_op
# 28                     https://m.cafe.naver.com/sqlpd
# 29             https://m.cafe.naver.com/bebettergirls
#
#                                         출처명      작성일자  \
# 0                              song's eyagi  20230406
# 1                                       바밤바  20230412
# 2                                    모비인사이드  20230310
# 3                   주들의 그리 대단하진 않지만 굉장한 이야기  20230322
# 4                               스터디채널 공식블로그  20230407
# 5          윈스펙｜자기계발, 내일배움카드, 토익스피킹, 공기업직업교육  20230406
# 6                                  jblove80  20230413
# 7                                      혀니파파  20230407
# 8                                  이룸114부동산  20230328
# 9             사회조사분석사 (S&Y) [조사/통계/SPSS/분석]  20230404
# 10                                비비디 바비디 부  20230328
# 11             -봉무동이시아폴리스 옥스포드어학원-중3, 수능마무리  20230311
# 12                        볼빨간 유부♡(,,>᎑<,,)♡  20230316
# 13                                       루멘  20230111
# 14                           WHIT ME MENTOS  20230319
# 15                                     인테리어  20230331
# 16                         Innocent Promise  20230406
# 17           자격증 뽀개기★전기기사,전기산업기사,전기기능사,공사기사  20230406
# 18                               구름이 쉬어가는 밤  20230411
# 19      스펙업｜취업,대학생,인턴,대기업,공기업,GSAT,대외활동,공모전  20230407
# 20  데이터 전문가 포럼 (빅데이터분석기사, ADP, SQLP, DAP 등)  20230328
# 21                한국과학기술정보연구원(KISTI) 공식 블로그  20230322
# 22         윈스펙｜자기계발, 내일배움카드, 토익스피킹, 공기업직업교육  20230227
# 23      공준모★공기업,채용,공공기관취업,NCS,자소서,인턴,공무직,한전  20230210
# 24                                      교육부  20230409
# 25             이기적 스터디 카페_컴활,정보처리,워드,데이터자격증  20230409
# 26                                   외식경영박사  20230117
# 27                       Excuse 美 Agnes : )  20230322
# 28  데이터 전문가 포럼 (빅데이터분석기사, ADP, SQLP, DAP 등)         3
# 29     취업대학교★대기업,공기업,GSAT,NCS,인턴,승무원,자소서,면접  20230329
#
#                                          제목 클릭 이동 URL  \
# 0   https://m.blog.naver.com/mintsorbet07/22306573...
# 1      https://m.blog.naver.com/jdnxx8z5/223073500429
# 2   https://m.post.naver.com/viewer/postView.naver...
# 3       https://m.blog.naver.com/urmyver/223052450425
# 4     https://m.blog.naver.com/waiting25/223067557203
# 5   https://m.cafe.naver.com/winspec/520414?art=ZX...
# 6      https://m.blog.naver.com/jblove80/223074260426
# 7      https://m.blog.naver.com/feia1230/223067522018
# 8       https://m.blog.naver.com/osojang/223058278536
# 9   https://m.cafe.naver.com/statclub/166670?art=Z...
# 10     https://m.blog.naver.com/ridesafe/223058079560
# 11   https://m.blog.naver.com/bestoxford/223040724738
# 12    https://m.blog.naver.com/hhee_0211/223046626195
# 13    https://m.blog.naver.com/hellstudy/222980833110
# 14   https://m.blog.naver.com/wonsstorne/223047495669
# 15  https://m.blog.naver.com/roseandme7753/2230606...
# 16       https://m.blog.naver.com/182544/223066859137
# 17  https://m.cafe.naver.com/mseller/77906?art=ZXh...
# 18    https://m.blog.naver.com/raonday92/223072613372
# 19  https://m.cafe.naver.com/specup/7252794?art=ZX...
# 20  https://m.cafe.naver.com/sqlpd/50740?art=ZXh0Z...
# 21    https://m.blog.naver.com/withkisti/223052086923
# 22  https://m.cafe.naver.com/winspec/451811?art=ZX...
# 23  https://m.cafe.naver.com/studentstudyhard/2278...
# 24      https://m.blog.naver.com/moeblog/223067500457
# 25  https://m.cafe.naver.com/yjbooks/83957?art=ZXh...
# 26       https://m.blog.naver.com/webkim/222987223321
# 27       https://m.blog.naver.com/she_op/223052780382
# 28  https://m.cafe.naver.com/sqlpd/51763?art=ZXh0Z...
# 29  https://m.cafe.naver.com/bebettergirls/1965648...
#
#                                           제목 클릭 실행 함수  \
# 0   return goOtherCR(this, 'a=rvw*x.link&r=1&i=900...
# 1   return goOtherCR(this, 'a=rvw*b.link&r=2&i=900...
# 2   return goOtherCR(this, 'a=rvw*p.link&r=3&i=000...
# 3   return goOtherCR(this, 'a=rvw*b.link&r=4&i=900...
# 4   return goOtherCR(this, 'a=rvw*x.link&r=5&i=900...
# 5   return goOtherCR(this, 'a=rvw*t.link&r=6&i=900...
# 6   return goOtherCR(this, 'a=rvw*b.link&r=7&i=900...
# 7   return goOtherCR(this, 'a=rvw*w.link&r=8&i=900...
# 8   return goOtherCR(this, 'a=rvw*b.link&r=9&i=900...
# 9   return goOtherCR(this, 'a=rvw*t.link&r=10&i=90...
# 10  return goOtherCR(this, 'a=rvw*b.link&r=13&i=90...
# 11  return goOtherCR(this, 'a=rvw*b.link&r=14&i=90...
# 12  return goOtherCR(this, 'a=rvw*b.link&r=15&i=90...
# 13  return goOtherCR(this, 'a=rvw*f.link&r=16&i=90...
# 14  return goOtherCR(this, 'a=rvw*b.link&r=17&i=90...
# 15  return goOtherCR(this, 'a=rvw*b.link&r=18&i=90...
# 16  return goOtherCR(this, 'a=rvw*b.link&r=19&i=90...
# 17  return goOtherCR(this, 'a=rvw*t.link&r=20&i=90...
# 18  return goOtherCR(this, 'a=rvw*b.link&r=21&i=90...
# 19  return goOtherCR(this, 'a=rvw*t.link&r=22&i=90...
# 20  return goOtherCR(this, 'a=rvw*c.link&r=23&i=90...
# 21  return goOtherCR(this, 'a=rvw*b.link&r=24&i=90...
# 22  return goOtherCR(this, 'a=rvw*t.link&r=25&i=90...
# 23  return goOtherCR(this, 'a=rvw*t.link&r=26&i=90...
# 24  return goOtherCR(this, 'a=rvw*b.link&r=27&i=90...
# 25  return goOtherCR(this, 'a=rvw*t.link&r=28&i=90...
# 26  return goOtherCR(this, 'a=rvw*f.link&r=29&i=90...
# 27  return goOtherCR(this, 'a=rvw*b.link&r=30&i=90...
# 28  return goOtherCR(this, 'a=rvw*c.link&r=31&i=90...
# 29  return goOtherCR(this, 'a=rvw*t.link&r=32&i=90...
#
#                                                    제목  \
# 0                             빅데이터분석기사 응시자격 확인 및 학습과정
# 1                               빅데이터분석기사 자격증 온라인 학습과정
# 2                       퍼포먼스 마케터가 데이터 분석 툴을 다뤄야 하는 이유
# 3                       데이터 분석가 : 원활한 취업을 위해 갖춰야 할 스펙
# 4                       빅데이터분석기사 자격증 강의로 필기 합격 자신감 완성
# 5                           빅데이터분석기사 시험일정, 시험시간 체크하기!
# 6                                 빅데이터분석기사 시험일정 확인하세요
# 7                   빅데이터분석기사 AI 시대 앞서나가는 빅데이터자격증 취득방법
# 8                           빅데이터분석기사 시험정보 확인하고 대비했어요!
# 9                          빅데이터분석기사 응시자격 : 가장 합리적인 방법
# 10                      데이터분석 준전문가 학원 : 빅데이터 기초부터 한번에
# 11                        빅데이터분석기사 자격증 취득조건 알아보고 준비하기
# 12                        빅데이터분석교육 :: 빅데이터학원에서 배우세요!!
# 13            2023년 빅데이터분석기사 자격증 시험일정(ADsP/DAsP/SQLD)
# 14                           빅데이터분석기사 응시자격 누가 제일 빠르나~
# 15                            데이터 분석가 취업이 신입으로 어려운 이유
# 16                              데이터분석준전문가 시험정보 및 취득방법
# 17                       빅데이터분석기사 필기 인강 합격률 올리기에 좋아요!
# 18                  빅데이터분석기사 자격요건 고졸 전문대졸도 학점은행제로 준비!
# 19                    [KIC캠퍼스] 자바기반 백엔드 & 빅데이터분석 양성과정
# 20                                 데이터 분석가 스터디 충원(마감)
# 21                      [KISTI 이벤트] '데이터분석본부' 영역 모의고사
# 22                        빅데이터분석기사 필기 시험일정/접수시간 알아보기!
# 23                    빅데이터분석기사 응시자격 온라인으로 최단기간에 준비하는법
# 24                                제5회 교육 공공데이터 분석활용대회
# 25                                제6회 빅데이터 분석기사 필기 후기
# 26  [2023년 1학기 외식업 빅데이터 분석과 활용] 11주차 수업, 데이터 분석 및 시각화
# 27                            빅데이터분석기사 교육받고 자격증 취득하기!
# 28                 '데이터분석'분야 실무 자격증이나 진로방향 조언 부탁드립니다.
# 29                                             데이터 분석
#
#                                                  요약내용
# 0   빅데이터분석기사 시험을 과목별로 분류해 살피자면 필기는 빅데이터 분석기획과 탐색, ...
# 1   빅데이터분석기사는 빅데이터 집합에서 유용한 정보를 찾아서 결과 예측을 위한 데이터를...
# 2   특히 데이터 분석가 중에서도 마케팅 쪽에서 데이터를 분석해보고 싶다는 니즈가 있었거...
# 3   #담당 업무 데이터 분석가가 담당하는 업무는 말 그대로 데이터를 분석하는 업무라서 ...
# 4   빅데이터 분석기사는 이러한 빅데이터에 대한 이해를 기반으로 분석 기획, 수집,저장 ...
# 5   빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 ...
# 6   근무하면서 데이터 분석을 통해 사용자들의 요구를 충족시키는 것을 파악하고 그것에 대...
# 7   그래서 빅데이터분석기사란 이러한 데이터의 분석 기획 그리고 수집 및 저장과 처리 그...
# 8   빅데이터 분석기획 2. 빅데이터 탐색 3. 빅데이터모델링 4. 빅데이터결과해석 이렇...
# 9   빅데이터분석기사 응시자격 : 가장 합리적인 방법 현대 사회를 보게되면 전문자격을 취...
# 10  마스터플랜 데이터 분석 - R기초와 데이터 마트 - 통계분석 - 정형 데이터 마이닝...
# 11  이를 토대로 데이터 분석 프로세스를 나눠 순차적으로 데이터를 수집 / 분석 / 해석...
# 12  가공&분석, 시각화까지 전부 핵심 기술들을 배워서 업무에 활용하거나 커리어에 도움 ...
# 13  [한전 자격가점 분야] [인국공 자격가점 분야] 경쟁이 가장 치열한 행정직의 경우 ...
# 14  마케팅 부서에서 제가 주로 하는 일은 데이터 분석을 하면서 인터넷 포털에 저희 사이...
# 15  신입 채용이 거의 없는 직무 - 기획자 성향 - 의사 결정자 성향 현업에서 데이터 ...
# 16  저는 취업 준비를 위해서 다양한 정보를 알아보던 중 데이터를 분석하는 전문가의 전망...
# 17  빅데이터분석기사 빅데이터 분석기사는 빅데이터 이해를 기반으로 분석 기획, 빅데이터 ...
# 18  먼저 빅데이터분석기사를 보기 위한 한국데이터진흥원에서 정해놓은 조건부터... 동일직...
# 19  빅데이터분석 양성과정 ○ 활동내용 기초부터 실무프로젝트완성 취업지원까지 전액무료교육...
# 20  현재 데이터 분석 스터디를 진행중인데 인원이 적어서 2~3명 정도 충원하려고 합니다...
# 21  한국과학기술정보연구원 유튜브 채널에 올라간 '"데이터 분석해 인사이트 드려요" 데이...
# 22  빅데이터분석기사 필기 시험의 시험시간은 총 120분이며, 빅데이터 분석기획 / 빅데...
# 23  관리하며 분석하는 직업을 빅데이터 분석기사라고 하죠 빅데이터를 관리하기 위해서는 매...
# 24  kr " " #교육공공데이터 #분석활용대회 #교육부 제5회 교육 공공데이터 분석활용...
# 25  제6회 빅데이터 분석기사 필기 시험을 응시한 직장인입니다. 전공은... 공부는 [2...
# 26  문서 속에 숨겨진 주제를 찾는 빅데이터 분석을 위한 통계적 모델 중의 하나입니다. ...
# 27  이에 따라 정형 및 비정형의 대용량 데이터를 구축, 탐색과 분석, 시각화하는 실습형...
# 28  개발/데이터분석 공모전 수상 등) 인데요 실무에 필요하고 도움이 많이 된다면 당연히...
# 29  데이터 분석 관련 자격증 비전공자가 따기 많이 어려울까요? 따 놓으면 마케팅 쪽에서...

# %% [markdown]
# - End Of Program
